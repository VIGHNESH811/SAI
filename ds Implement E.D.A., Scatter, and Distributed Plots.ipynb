# %% [markdown]
# <a href="https://colab.research.google.com/github/VIGHNESH811/SAI/blob/main/ds%20Implement%20E.D.A.%2C%20Scatter%2C%20and%20Distributed%20Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('employee_data.csv')
df.head()
# Out:
#    ID Gender  Experience (Years)               Position  Salary
# 0   1      F                   4        DevOps Engineer  109976
# 1   2      M                   6        DevOps Engineer  120088
# 2   3      M                  17          Web Developer  181301
# 3   4      M                   7  Systems Administrator   77530
# 4   5      F                  13  Systems Administrator  152397

# %%
df.shape
# Out:
# (400, 5)

# %%
df.describe()
# Out:
#                ID  Experience (Years)        Salary
# count  400.000000          400.000000     400.00000
# mean   200.500000            9.670000  131701.19750
# std    115.614301            6.101571   43351.50899
# min      1.000000            0.000000   43643.00000
# 25%    100.750000            4.000000  100484.75000
# 50%    200.500000           10.000000  128561.50000
# 75%    300.250000           15.000000  157735.00000
# max    400.000000           20.000000  269950.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  400 non-null    int64
#  1   Gender              400 non-null    object
#  2   Experience (Years)  400 non-null    int64
#  3   Position            400 non-null    object
#  4   Salary              400 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# scatter plot

# %%
import sys
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x, y)
plt.savefig('my_plot.png')

# %%
import sys
import matplotlib
matplotlib.use('Agg')
import numpy
import matplotlib.pyplot as plt
x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)
plt.scatter(x, y)
#plt.show()
plt.savefig('pht.png')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# to ignore the warnings
from warnings import filterwarnings
df=sns.load_dataset('tips')
# the first five entries of the dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Displot:

sns.set_style('whitegrid')
sns.displot(df['total_bill'], kde=False, color='red', bins =30)

# %%
#Joinplot:

sns.jointplot(x ='total_bill', y ='tip', data =df)

# %%
#Pairplot:

sns.pairplot(df)

# %%
#Rugplot:

sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>
